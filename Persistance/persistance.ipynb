# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
# Out:
# True

# %%
llm = model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic': 'Football'}, config=config1)
# Out:
# {'topic': 'Football',
#  'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated" and wanted to get to the "kick" of the problem.',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'Football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated" and wanted to get to the "kick" of the problem.', 'explanation': 'This joke is a play on words, using puns related to football to create a humorous effect. \n\nThe setup for the joke is "Why did the football go to the doctor?" which primes the listener to expect a reason related to health or injury. The punchline "it was feeling a little \'deflated\'" is a clever use of wordplay, as a football can be deflated in the literal sense (losing air pressure), but the word "deflated" also has a figurative meaning of feeling unenthusiastic or depressed. \n\nThe second part of the punchline, "and wanted to get to the \'kick\' of the problem," is another football-related pun. In this case, "kick" has a double meaning: in football, a kick is a way to propel the ball, but the phrase "get to the kick of the problem" is a play on the phrase "get to the root of the
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'Football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated" and wanted to get to the "kick" of the problem.', 'explanation': 'This joke is a play on words, using puns related to football to create a humorous effect. \n\nThe setup for the joke is "Why did the football go to the doctor?" which primes the listener to expect a reason related to health or injury. The punchline "it was feeling a little \'deflated\'" is a clever use of wordplay, as a football can be deflated in the literal sense (losing air pressure), but the word "deflated" also has a figurative meaning of feeling unenthusiastic or depressed. \n\nThe second part of the punchline, "and wanted to get to the \'kick\' of the problem," is another football-related pun. In this case, "kick" has a double meaning: in football, a kick is a way to propel the ball, but the phrase "get to the kick of the problem" is a play on the phrase "get to the root of th
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic': 'Cricket'}, config=config2)
# Out:
# {'topic': 'Cricket',
#  'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions and was struggling to "bat" away its problems.',
# ...

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions and was struggling to "bat" away its problems.', 'explanation': 'This joke is a play on words, using cricket terminology to create a pun. The setup for the joke is that a cricket ball is going to therapy, which is an unusual and unexpected scenario. The punchline relies on two key phrases: "bowled over" and "bat away."\n\nIn cricket, "bowled" refers to when a batsman is dismissed by a ball that hits the wicket. However, the phrase "bowled over" is also an idiomatic expression that means being completely overwhelmed or surprised by something. In this joke, the cricket ball is feeling "bowled over" by its emotions, implying that it\'s struggling to cope with its feelings.\n\nThe second part of the punchline, "bat away its problems," is another cricket reference. In the sport, a batsman uses a bat to hit the ball and score runs. Here
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions and was struggling to "bat" away its problems.', 'explanation': 'This joke is a play on words, using cricket terminology to create a pun. The setup for the joke is that a cricket ball is going to therapy, which is an unusual and unexpected scenario. The punchline relies on two key phrases: "bowled over" and "bat away."\n\nIn cricket, "bowled" refers to when a batsman is dismissed by a ball that hits the wicket. However, the phrase "bowled over" is also an idiomatic expression that means being completely overwhelmed or surprised by something. In this joke, the cricket ball is feeling "bowled over" by its emotions, implying that it\'s struggling to cope with its feelings.\n\nThe second part of the punchline, "bat away its problems," is another cricket reference. In the sport, a batsman uses a bat to hit the ball and score runs. Her
# ...

# %% [markdown]
# Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f167a3b-361c-6674-8000-159eb955d0d4"}})
# Out:
# StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_id': '1f167a3b-361c-6674-8000-159eb955d0d4'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-14T03:47:01.205566+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f167a3b-361c-6673-bfff-1dc9b8f47364'}}, tasks=(PregelTask(id='0806bfcd-362a-4042-363a-2b4eb5067b28', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions and was struggling to "bat" away its problems.'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "2", "checkpoint_id": "1f167a3b-361c-6674-8000-159eb955d0d4"}})
# Out:
# {'topic': 'Cricket',
#  'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions and was struggling to "bat" away its problems.',
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions and was struggling to "bat" away its problems.', 'explanation': 'This joke is a play on words, using cricket terminology to create a pun. The setup for the joke is that a cricket ball is going to therapy, which is an unusual and unexpected scenario. The punchline relies on two key phrases: "bowled over" and "bat away."\n\nIn cricket, "bowled" refers to when a batsman is dismissed by a ball that hits the wicket. However, the phrase "bowled over" is also an idiomatic expression that means being completely overwhelmed or surprised by something. In this joke, the cricket ball is feeling "bowled over" by its emotions, implying that it\'s struggling to cope with its feelings.\n\nThe second part of the punchline, "bat away its problems," is another cricket reference. In the sport, a batsman uses a bat to hit the ball and score runs. The
# ...

# %% [markdown]
# Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f167a43-e024-692d-8001-2b91f490c650", 'checkpoint_ns': ""}}, {'topic': "Tennis"})
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f167a5b-0741-66a5-8002-9c552ce4daf0'}}

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Tennis'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f167a5b-0741-66a5-8002-9c552ce4daf0'}}, metadata={'source': 'update', 'step': 2, 'parents': {}}, created_at='2026-06-14T04:01:15.285878+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f167a43-e024-692d-8001-2b91f490c650'}}, tasks=(PregelTask(id='8f1fcb8c-f22e-6ee7-8405-dab2eddae817', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...
